# %%
from src.datawrangling.clean_register import main

# %%
input_file = "../promprint-data/register_1863b/251104-1863b-full.csv"
output_folder = "../promprint-data/2026-06-16-datawrangling-v1.5.0-clean_register-1863b/"

main(input_file, output_folder)
