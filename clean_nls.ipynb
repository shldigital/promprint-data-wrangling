# %%
from src.datawrangling.clean_nls import main

# %%
input_folder = "../promprint-data/nls_catalog/"
output_folder = "../promprint-data/2026-06-16-datawrangling-v1.5.1-nls-catalog/"
config_file = "deprecated"

main(input_folder, output_folder, config_file)
# Out:
# Processing: ../promprint-data/nls_catalog/txtBIBLIOGRAPHIC_11573881650004341_18.txt
# Processing: ../promprint-data/nls_catalog/txtBIBLIOGRAPHIC_11573881650004341_43.txt
# Processing: ../promprint-data/nls_catalog/txtBIBLIOGRAPHIC_11573881650004341_35.txt
# Processing: ../promprint-data/nls_catalog/txtBIBLIOGRAPHIC_11573881650004341_33.txt
# Processing: ../promprint-data/nls_catalog/txtBIBLIOGRAPHIC_11573881650004341_02.txt
# Processing: ../promprint-data/nls_catalog/txtBIBLIOGRAPHIC_11573881650004341_27.txt
# Processing: ../promprint-data/nls_catalog/txtBIBLIOGRAPHIC_11573881650004341_11.txt
# Processing: ../promprint-data/nls_catalog/txtBIBLIOGRAPHIC_11573881650004341_09.txt
# Processing: ../promprint-data/nls_catalog/txtBIBLIOGRAPHIC_11573881650004341_01.txt
# Processing: ../promprint-data/nls_catalog/txtBIBLIOGRAPHIC_11573881650004341_20.txt
# Processing: ../promprint-data/nls_catalog/txtBIBLIOGRAPHIC_11573881650004341_31.txt
# ...
